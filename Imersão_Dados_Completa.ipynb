# %% [markdown]
# <a href="https://colab.research.google.com/github/MatheusRQ/Imersao_de_dados/blob/main/Imers%C3%A3o_Dados_Completa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Aula 01:

# %% [markdown]
# ##Feito em Aula

# %%
#Import da tabela "pandas"
import pandas as pd

#Import dos dados
url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'
#Consulta dos dados
dados = pd.read_csv(url_dados, compression = 'zip')
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
#consulta dos 5 primeiros itens da base
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
#Tamanho da base(Linhas, Colunas)
dados.shape
# Out:
# (23814, 877)

# %%
#Separação de uma coluna das outras
dados['tratamento']
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %%
#Tipos de itens diferentes presentes na coluna 'Tratamento'
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
#Tipos de itens diferentes presentes na coluna 'Tempo'

dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %%
#Tipos de itens diferentes presentes na coluna 'Dose'

dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
#Tipos de itens diferentes presentes na coluna 'Droga'

dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
#Tipos de itens diferentes presentes na coluna 'g-0'

dados['g-0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %%
#Quantidade de cada itens diferente na tabela 'Tratamento'
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
#Quantidade de cada itens diferente na tabela 'Tratamento' em proporção
dados['tratamento'].value_counts(normalize=True) ###Desafio 03 que foi realizado antes do termino da aula
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
#Quantidade de cada itens diferente na tabela 'Dose'

dados['dose'].value_counts()
# Out:
# D1    12147
# D2    11667
# Name: dose, dtype: int64

# %%
dados['dose'].value_counts(normalize = True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %%
#Grafico Pizza da tabela 'Tratamento'
dados['tratamento'].value_counts().plot.pie()

# %%
#Grafico Pizza da tabela 'Tempo'

dados['tempo'].value_counts().plot.pie()

# %%
#Grafico em Barras da tabela 'Tempo'

dados['tempo'].value_counts().plot.bar()

# %%
#Filtragem das linhas da base onde o item da coluna 'g-0' é maior que zero, sendo aplicado em uma View chamada "dados_filtrados"
dados_filtrados = dados[dados['g-0'] > 0]
dados_filtrados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]

# %% [markdown]
# ##Desafios

# %% [markdown]
# ###Desafio 01: Investigar por que a classe tratamento é tão desbalanceada?
#
# ###Desafio 02: Plotar as 5 últimas linhas da tabela.
#
# ###Desafio 03: Proporção das classes tratamento.
#
# ###Desafio 04: Quantos tipos de drogas foram investigados.
#
# ###Desafio 05: Procurar na documentação o métoro query(Pandas).
#
# ###Desafio 06: Renomear as colunas tirando o hifen.
#
# ###Desafio 07: Deixar os graficos bonitês.(Matplotlib.pyplot).
#
# ###Desafio 08: Resumo do que você aprendeu com os dados.

# %% [markdown]
# ###Desafio 01: Investigar por que a classe tratamento é tão desbalanceada?

# %% [markdown]
# No tipo "com_controle", todas as linhas utilizam a mesma droga, no caso, a 'cacb2b860', tendo apenas a variação nas outras variaveis. Por isso, é uma quantidade menor.

# %%
dados_droga = dados[dados['tratamento'] =='com_controle']
dados_droga['droga'].unique()
# Out:
# array(['cacb2b860'], dtype=object)

# %% [markdown]
# ###Desafio 02: Plotar as 5 últimas linhas da tabela.

# %%
#Fonte: https://pandas.pydata.org/docs/user_guide/basics.html?highlight=head#head-and-tail
dados.tail()
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %% [markdown]
# ###Desafio 03: Proporção das classes tratamento. (Repost)

# %%
#Fonte: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.core.groupby.SeriesGroupBy.value_counts.html?highlight=value_counts#pandas.core.groupby.SeriesGroupBy.value_counts
dados['tratamento'].value_counts(normalize=True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %% [markdown]
# ###Desafio 04: Quantos tipos de drogas foram investigados.

# %%
#Testados 3289 tipos de drogas
dados['droga'].value_counts().shape
# Out:
# (3289,)

# %% [markdown]
# ###Desafio 05: Procurar na documentação o métoro query(Pandas).

# %% [markdown]
# https://pandas.pydata.org/docs/user_guide/indexing.html#the-query-method

# %% [markdown]
# ###Desafio 06: Renomear as colunas tirando o hifen.

# %%
dados.columns = dados.columns.str.replace(r"-", "_")
dados
# Out:
#                  id    tratamento  tempo dose  ...    c_96    c_97    c_98    c_99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %% [markdown]
# ###Desafio 07: Deixar os graficos bonitês.(Matplotlib.pyplot)

# %%
#Nesse desafio essa biblioteca foi o que eu consegui encontrar, a minha fonte: https://pbpython.com/simple-graphing-pandas.html
dados['tempo'].value_counts().plot.bar(title = 'Tempo Que a experiencia foi realizada')
dados['tempo'].value_counts().plot.bar().set_xlabel('Tempo')
dados['tempo'].value_counts().plot.bar().set_ylabel("Quantidade de Experimentos")
# Out:
# Text(0, 0.5, 'Quantidade de Experimentos')

# %% [markdown]
# ###Desafio 08: Resumo do que você aprendeu com os dados.

# %%
dados['tempo'].value_counts().plot.bar(title = 'Tempo Que a experiencia foi realizada')
dados['tempo'].value_counts().plot.bar().set_xlabel('Tempo')
dados['tempo'].value_counts().plot.bar().set_ylabel("Quantidade de Experimentos")
# Out:
# Text(0, 0.5, 'Quantidade de Experimentos')

# %%
dados['dose'].value_counts().plot.bar(title = 'Dosagem')
dados['dose'].value_counts().plot.bar().set_xlabel('Número De Doses')
dados['dose'].value_counts().plot.bar().set_ylabel("Quantidade de Experimentos")
# Out:
# Text(0, 0.5, 'Quantidade de Experimentos')

# %%
dados['tratamento'].value_counts().plot.bar(title = 'Tipo de Tratamento')
dados['tratamento'].value_counts().plot.bar().set_xlabel('Com/Sem Droga')
dados['tratamento'].value_counts().plot.bar().set_ylabel("Quantidade de Experimentos")
# Out:
# Text(0, 0.5, 'Quantidade de Experimentos')

# %%
dados['droga'].value_counts()
# Out:
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
#              ...
# 277f1d6f9       1
# 1502f8cbb       1
# 98c94f9b9       1
# a9bc2c549       1
# 1a038f0f7       1
# Name: droga, Length: 3289, dtype: int64

# %% [markdown]
# Itens que são possiveis aprender com esses dados:
#  . O tempo mais utilizado nas experiencias é 48 horas
#  . A quantidade de dosagem mais utilizada é 1
#  . O tipo de tratamento mais utilizado é com drogas
#  . As 5 drogas mais utilizadas no experimento são:
#     cacb2b860     1866,
#     87d714366     718,
#     9f80f3f77     246,
#     8b87a7a83     203,
#     5628cb3ee     202

# %% [markdown]
# #Aula 02

# %% [markdown]
# ##Feito em aula

# %%
mapa = {'droga' : 'composto'}
dados.rename(columns=mapa, inplace = True)

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c_96    c_97    c_98    c_99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
cod_compostos = dados['composto'].value_counts().index[0:5]

# %%
cod_compostos
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %%
dados.query('composto in @cod_compostos')
# Out:
#                  id    tratamento  tempo dose  ...    c_96    c_97    c_98    c_99
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# 16     id_002fb9c19     com_droga     48   D1  ... -9.9840 -9.9840 -9.9840 -6.7840
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# 23802  id_fff3976bd     com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23805  id_fff6df1c5     com_droga     48   D2  ...  0.1516  0.4503 -0.6312 -0.8302
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()
plt.figure(figsize=(8,6))
ax = sns.countplot(x = 'composto', data=dados.query('composto in @cod_compostos'))
ax.set_title('Top 5 Compostos')
plt.show()

# %%
len (dados['g_0'].unique())
# Out:
# 14367

# %%
dados['g_0'].min()
# Out:
# -5.513

# %%
dados['g_0'].max()
# Out:
# 10.0

# %%
dados['g_0'].hist(bins = 100)

# %%
dados['g_19'].hist(bins = 100)

# %%
dados.describe()
# Out:
#               tempo           g_0  ...          c_98          c_99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      48.020156      0.248366  ...     -0.470252     -0.301505
# std       19.402807      1.393399  ...      1.834828      1.407918
# min       24.000000     -5.513000  ...    -10.000000    -10.000000
# 25%       24.000000     -0.473075  ...     -0.592600     -0.562900
# 50%       48.000000     -0.008850  ...      0.014000     -0.019500
# 75%       72.000000      0.525700  ...      0.461275      0.438650
# max       72.000000     10.000000  ...      3.111000      3.805000
#
# [8 rows x 873 columns]

# %%
dados[['g_0','g_1']]
# Out:
#           g_0     g_1
# 0      1.0620  0.5577
# 1      0.0743  0.4087
# 2      0.6280  0.5817
# 3     -0.5138 -0.2491
# 4     -0.3254 -0.4009
# ...       ...     ...
# 23809  0.1394 -0.0636
# 23810 -1.3260  0.3478
# 23811  0.3942  0.3756
# 23812  0.6660  0.2324
# 23813 -0.8598  1.0240
#
# [23814 rows x 2 columns]

# %%
dados.loc[:,'g_0':'g_771'].describe()
# Out:
#                 g_0           g_1  ...         g_770         g_771
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean       0.248366     -0.095684  ...     -0.219210      0.101524
# std        1.393399      0.812363  ...      1.326193      1.417674
# min       -5.513000     -5.737000  ...    -10.000000    -10.000000
# 25%       -0.473075     -0.562200  ...     -0.554400     -0.523800
# 50%       -0.008850     -0.046600  ...      0.028700     -0.006500
# 75%        0.525700      0.403075  ...      0.496400      0.536950
# max       10.000000      5.039000  ...     10.000000     10.000000
#
# [8 rows x 772 columns]

# %%
dados.loc[:,'g_0':'g_771'].describe().T['mean'].hist(bins=30)

# %%
dados.loc[:,'g_0':'g_771'].describe().T['min'].hist(bins=30)

# %%
dados.loc[:,'g_0':'g_771'].describe().T['max'].hist(bins=30)

# %%
dados.loc[:, 'c_0': 'c_99'].describe().T['mean'].hist(bins=50)

# %%
sns.boxplot(x= 'g_0', data=dados)

# %%
plt.figure(figsize = (10,8))
sns.boxplot(y= 'g_0', x= 'tratamento', data=dados)

# %% [markdown]
# ##Desafios

# %% [markdown]
# ###Desafio 01: Ordenar o gráfico coutplot
# ###(E plotar os outros graficos utilizando o countlot)
#
# ###Desafio 02: Melhorar a visualização alterando tamanho da fonte...
# ###(traduzindo o "count", deixando a primeira letra em maiusculo, etc)
#
# ###Desafio 03: Plotar os histogramas com seaborn
#
# ###Desafio 04: Estudar sobre as estatísticas retornadas no .describe
#
# ###Desafio 05: Refletir sobre a manipulação do tamanho das visualizações.
#
# ###Desafio 06: Fazer outras analises com o boxplot e até com o histograma.
#
# ###Desario 07: Resumo do que você aprendeu com os dados

# %% [markdown]
# ###Desafio 01: Ordenar o gráfico coutplot

# %%
cod_compostos = dados['composto'].value_counts().index[0:5]

# %%
#import seaborn as sns
#import matplotlib.pyplot as plt
#sns.set()
plt.figure(figsize=(8,6))
ax = sns.countplot(x = 'composto', data=dados.query('composto in @cod_compostos'), order = dados['composto'].value_counts().index[0:5])
ax.set_title('Top 5 Compostos')
plt.show()

# %% [markdown]
# ###Desafio 02: Melhorar a visualização alterando tamanho da fonte... (traduzindo o "count", deixando a primeira letra em maiusculo, etc)

# %%
#import seaborn as sns
#import matplotlib.pyplot as plt
#sns.set()
plt.figure(figsize=(8,6))
ax = sns.countplot(x = 'composto', data=dados.query('composto in @cod_compostos'), order = dados['composto'].value_counts().index[0:5])
ax.set_title('Top 5 Compostos', size = 20)
plt.ylabel('Quantidade de Experimentos', size = 15)
plt.xlabel('Composto', size = 15)

plt.show()

# %% [markdown]
# ###Desafio 03: Plotar os histogramas com seaborn

# %%
plt.figure(figsize = (10,8))
ax = sns.histplot(data =dados.loc[:,'g_0':'g_771'].describe().T['mean'], bins = 30)
ax.set_title('Média da variação do RNAs dos Genes', size = 20)
plt.ylabel('Quantidade', size = 15)
plt.xlabel('Média', size = 15)
# Out:
# Text(0.5, 0, 'Média')

# %%
plt.figure(figsize = (10,8))
ax = sns.histplot(data = dados.loc[:,'g_0':'g_771'].describe().T['min'], bins = 30)
ax.set_title('Minimo da variação do RNAs dos Genes', size = 20)
plt.ylabel('Quantidade', size = 15)
plt.xlabel('Minimo', size = 15)
# Out:
# Text(0.5, 0, 'Minimo')

# %%
plt.figure(figsize = (10,8))
ax = sns.histplot(data = dados.loc[:,'g_0':'g_771'].describe().T['max'], bins = 30)
ax.set_title('Máximo da variação do RNAs dos Genes', size = 20)
plt.ylabel('Quantidade', size = 15)
plt.xlabel('Máximo', size = 15)
# Out:
# Text(0.5, 0, 'Máximo')

# %%
plt.figure(figsize = (10,8))
ax = sns.histplot(dados.loc[:, 'c_0': 'c_99'].describe().T['mean'], bins = 50)
ax.set_title('Média da variação do RNAs dos Compostos Celulares', size = 20)
plt.ylabel('Quantidade', size = 15)
plt.xlabel('Média', size = 15)
# Out:
# Text(0.5, 0, 'Média')

# %% [markdown]
# ###Desafio 04: Estudar sobre as estatísticas retornadas no .describe

# %% [markdown]
# Count: Retorna o número de linhas que aquela coluna possui

# %% [markdown]
# Mean: Retorna a média aritmetica. Deve ser usada com cuidado, pois, se utilizarmos varios itens com valores baixos e um com valores altos, a media será um valor mediano, o que pode não ser o resultado esperado

# %% [markdown]
# std: Retorna o desvio de padrão, ou seja, a maior variação presente da média

# %% [markdown]
# min e max: retornam, sucessivamente, o valor minimo e o maximo dos dados

# %% [markdown]
# 25%, 50%, 70%: retornam, sucessivamente, 25, 50 e 75% da quantidade dos dados. Eles também podem ser chamados de "Quartils", e o 50% também pode ser chamado de "mediana"

# %% [markdown]
# ###Desafio 05: Refletir sobre a manipulação do tamanho das visualizações.

# %% [markdown]
# Acredito que a sensação de "distorção" seja pois, com a quantidade tanto de dados quanto de excedentes, a Boxplot acabe ficando muito achatada, por isso o tamanho de sua visualização é um dos passos necessarios para que se tenha uma visão mais limpa.

# %% [markdown]
# ###Desafio 06: Fazer outras analises com o boxplot e até com o histograma.

# %%
plt.figure(figsize = (10,8))
ax = sns.histplot(data = dados.loc[:,'g_0':'g_771'].describe().T['std'], bins = 30)
ax.set_title('Desvio de Padrão(STD) dos RNAs dos Genes', size = 20)
plt.ylabel('Quantidade', size = 15)
plt.xlabel('STD', size = 15)
# Out:
# Text(0.5, 0, 'STD')

# %%
plt.figure(figsize = (10,8))
ax = sns.histplot(dados.loc[:, 'c_0': 'c_99'].describe().T['std'], bins = 50)
ax.set_title('Desvio de Padrão(STD) dos RNAs dos Compostos Celulares', size = 20)
plt.ylabel('Quantidade', size = 15)
plt.xlabel('Média', size = 15)
# Out:
# Text(0.5, 0, 'Média')

# %% [markdown]
# ###Desafio 07: Resumo do que você aprendeu com os dados

# %% [markdown]
# Com os códigos de hoje, foi possivel verificar que a aproximação feita para chegar no resultado das colunas "g_X" pode ter sido um tanto brusca, vendo o máximo e o mínimo da variação de RNA presente. Também é possivel ver uma enorme concentração da média no ponto 0, abaixando muito para os lados, fazendo então uma curva simples. Também é possivel reparar que o STD forma um histograma Bimodal (de 2 picos). Já nas colunas "c_X", pode se reparar uma média mais distorcida para a esquerda, e um STD mais voltado para a direita.

# %% [markdown]
# #Aula 03

# %% [markdown]
# ##Feito em Aula

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c_96    c_97    c_98    c_99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
pd.crosstab(dados['dose'], dados['tempo'])
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'])
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'],normalize = 'index')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values = dados['g_0'], aggfunc = 'mean')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %%
dados[['g_0','g_3']]
# Out:
#           g_0     g_3
# 0      1.0620 -0.6208
# 1      0.0743  0.0604
# 2      0.6280 -0.0764
# 3     -0.5138  0.5288
# 4     -0.3254  0.6919
# ...       ...     ...
# 23809  0.1394 -0.5080
# 23810 -1.3260  0.9905
# 23811  0.3942 -0.7389
# 23812  0.6660  0.2044
# 23813 -0.8598  0.7952
#
# [23814 rows x 2 columns]

# %%
sns.scatterplot(x='g_0', y='g_3', data=dados)

# %%
sns.scatterplot(x='g_0', y='g_8', data=dados)

# %%
sns.lmplot(data=dados, x= 'g_0', y='g_8', line_kws={'color': 'red'})

# %%
sns.lmplot(data=dados, x= 'g_0', y='g_8', line_kws={'color': 'red'}, col='tratamento')

# %%
sns.lmplot(data=dados, x= 'g_0', y='g_8', line_kws={'color': 'red'}, col='tratamento', row='tempo')

# %%
dados.loc[:,'g_0':'g_771'].corr()
# Out:
#             g_0       g_1       g_2  ...     g_769     g_770     g_771
# g_0    1.000000  0.086032  0.176188  ... -0.127375 -0.514201  0.405908
# g_1    0.086032  1.000000 -0.054518  ... -0.006866 -0.095108 -0.032233
# g_2    0.176188 -0.054518  1.000000  ...  0.014489 -0.078661  0.103985
# g_3    0.011266 -0.027855  0.042633  ... -0.206077 -0.002142  0.058219
# g_4    0.403153  0.193647  0.013968  ... -0.172727 -0.363673  0.250713
# ...         ...       ...       ...  ...       ...       ...       ...
# g_767 -0.052622 -0.003378 -0.053149  ...  0.065450  0.008603 -0.001136
# g_768  0.300241 -0.030756  0.115415  ...  0.079364 -0.382607  0.351651
# g_769 -0.127375 -0.006866  0.014489  ...  1.000000  0.135853 -0.083713
# g_770 -0.514201 -0.095108 -0.078661  ...  0.135853  1.000000 -0.425063
# g_771  0.405908 -0.032233  0.103985  ... -0.083713 -0.425063  1.000000
#
# [772 rows x 772 columns]

# %%
corr = dados.loc[:,'g_0':'g_50'].corr()

# %%
import numpy as np


# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
corr_celular = dados.loc[:,'c_0':'c_50'].corr()

# %%
corr_celular = dados.loc[:,'c_0':'c_50'].corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_celular, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_celular, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# ##Desafios

# %% [markdown]
# ###Desafio 01: Criar tabelas de frequência com o pandas.groupby()
#
# ###Desafio 02: Normalizar o crosstab pela coluna.
#
# ###Desafio 03: Explorar outros agregadores.
#
# ###Desafio 04: Explorar o melt.
#
# ###Desafio 05: Calcular e analisar a correlação entre G e C. Refletir sobre os efeitos biológicos.
#
# ###Desafio 06: Estudar o código que plota a matriz de correlação (heatmap)
#
# ###Desafio 07: Resumo do que você aprendeu com os dados

# %% [markdown]
# ###Desafio 01: Criar tabelas de frequência com o pandas.groupby()

# %%
pd.crosstab(dados['dose'], dados['tempo'])
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %%
dados.groupby(['dose','tempo'])['tratamento'].value_counts().unstack()
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %% [markdown]
# ###Desafio 02: Normalizar o crosstab pela coluna.

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'],normalize = 'columns')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.161308   0.163341
#      48         0.183816   0.182750
#      72         0.164523   0.164024
# D2   24         0.163451   0.163158
#      48         0.163451   0.163614
#      72         0.163451   0.163113

# %% [markdown]
# ###Desafio 03: Explorar outros agregadores.

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values = dados['g_0'], aggfunc = 'std')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.751395   1.461954
#      48         0.853396   1.693903
#      72         0.769294   1.458600
# D2   24         0.836626   1.044999
#      48         0.836845   1.315476
#      72         0.878041   1.451532

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values = dados['g_0'], aggfunc = 'min')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24           -2.370     -5.183
#      48           -3.276     -5.420
#      72           -2.086     -5.261
# D2   24           -2.135     -5.233
#      48           -4.859     -4.567
#      72           -1.909     -5.513

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values = dados['g_0'], aggfunc = 'max')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24            3.226      9.908
#      48            3.423     10.000
#      72            2.584      9.355
# D2   24            2.601      7.167
#      48            4.335     10.000
#      72            4.670     10.000

# %% [markdown]
# ###Desafio 04: Explorar o melt.

# %%
pd.melt(dados, id_vars = ['dose','tempo','tratamento'],value_vars =['g_0'] )
# Out:
#       dose  tempo    tratamento variable   value
# 0       D1     24     com_droga      g_0  1.0620
# 1       D1     72     com_droga      g_0  0.0743
# 2       D1     48     com_droga      g_0  0.6280
# 3       D1     48     com_droga      g_0 -0.5138
# 4       D2     72     com_droga      g_0 -0.3254
# ...    ...    ...           ...      ...     ...
# 23809   D2     24     com_droga      g_0  0.1394
# 23810   D2     24     com_droga      g_0 -1.3260
# 23811   D2     48  com_controle      g_0  0.3942
# 23812   D1     24     com_droga      g_0  0.6660
# 23813   D1     72     com_droga      g_0 -0.8598
#
# [23814 rows x 5 columns]

# %% [markdown]
# ###Desafio 05: Calcular e analisar a correlação entre G e C. Refletir sobre os efeitos biológicos.

# %%
cols_genes = [f'g_{i}' for i in range(0, 51)]

# %%
cols_celular = [f'c_{i}' for i in range(0, 51)]

# %%
corr_mat = dados[cols_genes+cols_celular].corr().loc[cols_celular,cols_genes]

# %%
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_mat, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()

# %% [markdown]
# ###Desafio 06: Estudar o código que plota a matriz de correlação (heatmap)

# %%
corr = dados.loc[:,'g_0':'g_50'].corr()

# %%
import numpy as np

sns.set_theme(style="white")
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# ###Desafio 07: Resumo do que você aprendeu com os dados

# %% [markdown]
# Aprendi que, com a tabela de frequencia, o resultado do tratamento, separado em dose e tempo, da um número bastante equilibrado tanto para com_droga quanto para com_tratamento. Além disso, que existe uma correlação entre o aumento de RNA do g-0 em relação a diminuição do g-8, embora não exista necessariamente uma casualidade entre ambos. Alé, é claro, de uma correlação alta dos C, se sempre se mantém alto.

# %% [markdown]
# #Aula 04

# %% [markdown]
# ##Feito em aula

# %%
dados_resultados = pd.read_csv('https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_resultados.csv?raw=true')
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dados_resultados['acetylcholine_receptor_agonist'].unique()
# Out:
# array([0, 1])

# %%
dados_resultados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23814 entries, 0 to 23813
# Columns: 207 entries, id to wnt_inhibitor
# dtypes: int64(206), object(1)
# memory usage: 37.6+ MB

# %%
contagem_moa = dados_resultados.select_dtypes('int64').sum().sort_values(ascending=False)
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
contagem_moa = dados_resultados.drop('id', axis=1).sum().sort_values(ascending=False)
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
dados_resultados.drop('id',axis=1).sum(axis=1)
# Out:
# 0        1
# 1        0
# 2        3
# 3        0
# 4        1
#         ..
# 23809    1
# 23810    1
# 23811    0
# 23812    1
# 23813    0
# Length: 23814, dtype: int64

# %%
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c_96    c_97    c_98    c_99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados_resultados['n_moa'] = dados_resultados.drop('id',axis=1).sum(axis=1)

# %%
dados_resultados['n_moa'] != 0
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 23809     True
# 23810     True
# 23811    False
# 23812     True
# 23813    False
# Name: n_moa, Length: 23814, dtype: bool

# %%
dados_resultados['ativo_moa'] = (dados_resultados['n_moa'] != 0)
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %%
dados_combinados = pd.merge(dados, dados_resultados[['id','n_moa', 'ativo_moa']], on='id')
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...    c_98    c_99  n_moa  ativo_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      1       True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      3       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125      1       True
#
# [5 rows x 879 columns]

# %%
dados_combinados.query('tratamento == "com_controle"')['ativo_moa'].value_counts()
# Out:
# False    1866
# Name: ativo_moa, dtype: int64

# %%
dados_combinados.query('tratamento == "com_droga"')['ativo_moa'].value_counts()
# Out:
# True     14447
# False     7501
# Name: ativo_moa, dtype: int64

# %%
composto_principal = dados_combinados['composto'].value_counts().index[:5]
plt.figure(figsize=(12,8))
sns.boxplot(data = dados_combinados.query('composto in @composto_principal'), y='g_0', x='composto', hue='ativo_moa')

# %% [markdown]
# ##Desafios

# %% [markdown]
# ###Desafio 01: Encontrar o top 10 das ações do MOA (inibidor, agonista...)
#
# ###Desafio 02: Criar a coluna eh_controle para qundo na linha tratamento == com_controle
#
# ##Desafio 03: Criar três colunas para indicar o tempo 24, 48, 72
#
# ###Desafio 04: Estudar sobre combinações de DF https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
#
# ###Desafio 05: Fazer análise mais detalhada considerando tempo e dose, para comparar as distruibuições (Escolher uma droga e comparar com controle)
#
# ###Desafio 06: Descobrir se temos algum composto que, dependendo da configuração do experimento, ativa ou não ativa algum MOA
#
# ###Desafio 07: Descobrir se temos algum composto que, dependendo da configuração do experimento, ativa MOAs diferentes
#
# ###Desafio 08: Resumo do que você aprendeu com os dados.

# %% [markdown]
# ###Desafio 01: Encontrar o top 10 das ações do MOA (inibidor, agonista...)

# %%
dados_resultados.drop(['id','n_moa',"ativo_moa"],axis=1).sum()
# Out:
# 5-alpha_reductase_inhibitor               17
# 11-beta-hsd1_inhibitor                    18
# acat_inhibitor                            24
# acetylcholine_receptor_agonist           190
# acetylcholine_receptor_antagonist        301
#                                         ...
# ubiquitin_specific_protease_inhibitor      6
# vegfr_inhibitor                          170
# vitamin_b                                 26
# vitamin_d_receptor_agonist                39
# wnt_inhibitor                             30
# Length: 206, dtype: int64

# %%
dados_teste = pd.melt(dados_resultados.drop(['id','n_moa',"ativo_moa"],axis=1)).value_counts()

# %%
dados_teste
# Out:
# variable                                    value
# atp-sensitive_potassium_channel_antagonist  0        23813
# erbb2_inhibitor                             0        23813
# steroid                                     0        23808
# tropomyosin_receptor_kinase_inhibitor       0        23808
# leukotriene_inhibitor                       0        23808
#                                                      ...
# protein_phosphatase_inhibitor               1            6
# retinoid_receptor_antagonist                1            6
# calcineurin_inhibitor                       1            6
# erbb2_inhibitor                             1            1
# atp-sensitive_potassium_channel_antagonist  1            1
# Length: 412, dtype: int64

# %%
dados_resultados.T
# Out:
#                                        0      ...         23813
# id                              id_000644bb2  ...  id_ffffdd77b
# 5-alpha_reductase_inhibitor                0  ...             0
# 11-beta-hsd1_inhibitor                     0  ...             0
# acat_inhibitor                             0  ...             0
# acetylcholine_receptor_agonist             0  ...             0
# ...                                      ...  ...           ...
# vitamin_b                                  0  ...             0
# vitamin_d_receptor_agonist                 0  ...             0
# wnt_inhibitor                              0  ...             0
# n_moa                                      1  ...             0
# ativo_moa                               True  ...         False
#
# [209 rows x 23814 columns]

# %%
dados_resultados.filter(regex='$_$', axis=0)
# Out:
# Empty DataFrame
# ...

# %%
dados_troc = dados_resultados.drop(['id','n_moa',"ativo_moa"],axis=1)
dados_troc = dados_troc.columns.str.replace('column like $_', '')
dados_troc
# Out:
# Index(['5-alpha_reductase_inhibitor', '11-beta-hsd1_inhibitor',
#        'acat_inhibitor', 'acetylcholine_receptor_agonist',
#        'acetylcholine_receptor_antagonist', 'acetylcholinesterase_inhibitor',
#        'adenosine_receptor_agonist', 'adenosine_receptor_antagonist',
#        'adenylyl_cyclase_activator', 'adrenergic_receptor_agonist',
#        ...
#        'tropomyosin_receptor_kinase_inhibitor', 'trpv_agonist',
#        'trpv_antagonist', 'tubulin_inhibitor', 'tyrosine_kinase_inhibitor',
#        'ubiquitin_specific_protease_inhibitor', 'vegfr_inhibitor', 'vitamin_b',
#        'vitamin_d_receptor_agonist', 'wnt_inhibitor'],
#       dtype='object', length=206)

# %%
dados_resultados_sufix = [name.split('_')[-1] for name in contagem_moa.index]
dados_resultados_sufix_count = pd.DataFrame(data={'acao':dados_resultados_sufix,'contagem':contagem_moa.values})
top10_acoes = dados_resultados_sufix_count.groupby(by=['acao']).sum()['contagem'].sort_values(ascending=False)[:10]

plt.figure(figsize = (14,8))

ax = sns.barplot(x = top10_acoes.values, y = top10_acoes.index)

#for p in ax.patches:
#    width = p.get_width()
#    ax.text(width + 1,
#            p.get_y() + p.get_height() / 2,
#            '{:1.0f}',format(width),
#            ha = 'left',
#            va = 'center')
    
plt.title('Top 10 ações MOA', fontsize = 10)
plt.ylabel('Ação', fontsize = 15)
plt.xlabel('Quantidade', fontsize = 15)

plt.show()

# %% [markdown]
# ###Desafio 02: Criar a coluna eh_controle para quando na linha tratamento == com_controle

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c_96    c_97    c_98    c_99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados_combinados_1 = pd.merge(dados_resultados, dados[['id','tratamento']], on ='id')
dados_combinados_1['eh_controle'] = (dados_combinados_1['tratamento'] != 'com_droga')
dados_combinados_1
# Out:
#                  id  5-alpha_reductase_inhibitor  ...    tratamento  eh_controle
# 0      id_000644bb2                            0  ...     com_droga        False
# 1      id_000779bfc                            0  ...     com_droga        False
# 2      id_000a6266a                            0  ...     com_droga        False
# 3      id_0015fd391                            0  ...     com_droga        False
# 4      id_001626bd3                            0  ...     com_droga        False
# ...             ...                          ...  ...           ...          ...
# 23809  id_fffb1ceed                            0  ...     com_droga        False
# 23810  id_fffb70c0c                            0  ...     com_droga        False
# 23811  id_fffc1c3f4                            0  ...  com_controle         True
# 23812  id_fffcb9e7c                            0  ...     com_droga        False
# 23813  id_ffffdd77b                            0  ...     com_droga        False
#
# ...

# %%
dados_combinados_1["eh_controle"] = dados_combinados_1["eh_controle"].astype(int)

# %%
dados_combinados_1
# Out:
#                  id  5-alpha_reductase_inhibitor  ...    tratamento  eh_controle
# 0      id_000644bb2                            0  ...     com_droga            0
# 1      id_000779bfc                            0  ...     com_droga            0
# 2      id_000a6266a                            0  ...     com_droga            0
# 3      id_0015fd391                            0  ...     com_droga            0
# 4      id_001626bd3                            0  ...     com_droga            0
# ...             ...                          ...  ...           ...          ...
# 23809  id_fffb1ceed                            0  ...     com_droga            0
# 23810  id_fffb70c0c                            0  ...     com_droga            0
# 23811  id_fffc1c3f4                            0  ...  com_controle            1
# 23812  id_fffcb9e7c                            0  ...     com_droga            0
# 23813  id_ffffdd77b                            0  ...     com_droga            0
#
# ...

# %% [markdown]
# ###Desafio 03: Criar três colunas para indicar o tempo 24, 48, 72

# %%
dados_combinados_1 = pd.merge(dados_combinados_1, dados[['id','tempo']], on ='id')
dados_combinados_1['24h'] = (dados_combinados_1['tempo'] == 24)
dados_combinados_1['48h'] = (dados_combinados_1['tempo'] == 48)
dados_combinados_1['72h'] = (dados_combinados_1['tempo'] == 72)
dados_combinados_1['24h'] = dados_combinados_1['24h'].astype(int)
dados_combinados_1['48h'] = dados_combinados_1['48h'].astype(int)
dados_combinados_1['72h'] = dados_combinados_1['72h'].astype(int)
dados_combinados_1
# Out:
#                  id  5-alpha_reductase_inhibitor  ...  48h  72h
# 0      id_000644bb2                            0  ...    0    0
# 1      id_000779bfc                            0  ...    0    1
# 2      id_000a6266a                            0  ...    1    0
# 3      id_0015fd391                            0  ...    1    0
# 4      id_001626bd3                            0  ...    0    1
# ...             ...                          ...  ...  ...  ...
# 23809  id_fffb1ceed                            0  ...    0    0
# 23810  id_fffb70c0c                            0  ...    0    0
# 23811  id_fffc1c3f4                            0  ...    1    0
# 23812  id_fffcb9e7c                            0  ...    0    0
# 23813  id_ffffdd77b                            0  ...    0    1
#
# [23814 rows x 215 columns]

# %% [markdown]
# ###Desafio 04: Estudar sobre combinações de DF https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html

# %% [markdown]
# ###Desafio 05: Fazer análise mais detalhada considerando tempo e dose, para comparar as distruibuições (Escolher uma droga e comparar com controle)

# %%
composto_escolhido = dados_combinados['composto'].value_counts().index[1:2]
plt.figure(figsize=(12,8))
sns.catplot(x='composto', y='g_0', hue='tempo', col='dose', data=dados_combinados.query('composto in @composto_escolhido'), kind='box', height=4, aspect=.7)

# %% [markdown]
# ###Desafio 06: Descobrir se temos algum composto que, dependendo da configuração do experimento, ativa ou não ativa algum MOA

# %%
np.mean([True, True, True])
# Out:
# 1.0

# %%
np.mean([False, False, False])
# Out:
# 0.0

# %%
np.mean([True, False, True])
# Out:
# 0.6666666666666666

# %%
dados_combinados.groupby('composto').ativo_moa.mean().value_counts()
# Out:
# True     2076
# False    1213
# Name: ativo_moa, dtype: int64

# %% [markdown]
# ###Desafio 07: Descobrir se temos algum composto que, dependendo da configuração do experimento, ativa MOAs diferentes

# %%
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %%
dados_combinados_resultados = pd.merge(dados[['id', 'composto']],
                                       dados_resultados.drop(['n_moa', 'ativo_moa',
                                                              ], axis=1), on='id')
dados_combinados_resultados.head()
# Out:
#              id   composto  ...  vitamin_d_receptor_agonist  wnt_inhibitor
# 0  id_000644bb2  b68db1d53  ...                           0              0
# 1  id_000779bfc  df89a8e5a  ...                           0              0
# 2  id_000a6266a  18bb41b2c  ...                           0              0
# 3  id_0015fd391  8c7f86626  ...                           0              0
# 4  id_001626bd3  7cbed3131  ...                           0              0
#
# [5 rows x 208 columns]

# %%
def verifica(variacoes_composto):
    padroes = variacoes_composto.iloc[:,2:].value_counts()
    lista = []
    if len(padroes) > 1:
      lista.append(padroes)
    return lista

# %%
resultado = dados_combinados_resultados.groupby('composto').apply(verifica)

# %%
for linha in resultado:
  if len(linha):
    print(linha)

# %% [markdown]
# ###Desafio 08: Resumo do que você aprendeu com os dados.

# %% [markdown]
# Com os dados de hoje, podemos analisar que, os resultados nos inhibitor's são desparadamente o que teve um número de ativações mais alta, seguido pelo antagonist e pelo agonist. Também podemos analisar que não tiveram-se ativações na coluna "com_controle" no g_0, o que é algo positivo, já que era uma coluna da qual não deveria mesmo ter mudanças. Também somos capazes de verificar que todos os experimentos ativaram algo em alguma condição.

# %% [markdown]
# #Aula 05

# %% [markdown]
# ##Feito em Aula

# %%
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...    c_98    c_99  n_moa  ativo_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      1       True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      3       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125      1       True
#
# [5 rows x 879 columns]

# %%
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x,y, test_size = 0.2, stratify=y, random_state = 376)

modelo_rlogistica = LogisticRegression(max_iter=1000)
modelo_rlogistica.fit(x_treino, y_treino)
modelo_rlogistica.score(x_teste, y_teste)
# Out:
# 0.6267058576527399

# %%
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score

modelo_dummy = DummyClassifier('most_frequent')
modelo_dummy.fit(x_treino, y_treino)
previsao_dummy = modelo_dummy.predict(x_teste)
accuracy_score(y_teste, previsao_dummy)
# Out:
# 0.6067604450976275

# %%
dados_combinados['ativo_moa'].value_counts(normalize = True)
# Out:
# True     0.60666
# False    0.39334
# Name: ativo_moa, dtype: float64

# %%
from sklearn.tree import DecisionTreeClassifier


x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x,y, test_size = 0.2, stratify=y, random_state = 376)

modelo_arvore = DecisionTreeClassifier(max_depth = 3)
modelo_arvore.fit(x_treino, y_treino)
modelo_arvore.score(x_teste, y_teste)
# Out:
# 0.6105395758975436

# %%
from sklearn import tree

fig, ax = plt.subplots(figsize=(15, 10), facecolor='k')
tree.plot_tree(modelo_arvore,
               ax=ax,
               fontsize=10,
               rounded=True,
               filled=True,
               feature_names=x_treino.columns,
               class_names=['Não Ativado', 'Ativado'])
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier


x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x,y, test_size = 0.2, stratify=y, random_state = 376)

teste=[]
treino=[]
for i in range(1,15):
  modelo_arvore = DecisionTreeClassifier(max_depth = i)
  modelo_arvore.fit(x_treino, y_treino)
  teste.append(modelo_arvore.score(x_teste, y_teste))
  treino.append(modelo_arvore.score(x_treino, y_treino))

# %%
teste
# Out:
# [0.6067604450976275,
#  0.6067604450976275,
#  0.6105395758975436,
#  0.6204073063195465,
#  0.6204073063195465,
#  0.6183077892084821,
#  0.6208272097417594,
#  0.6208272097417594,
#  0.6172580306529498,
#  0.6145286584085661,
#  0.6115893344530758,
#  0.6017216040310729,
#  0.5958429561200924,
#  0.5968927146756247]

# %%
treino
# Out:
# [0.6066348223190384,
#  0.6066348223190384,
#  0.6211222508004829,
#  0.6360820954280615,
#  0.6412261823526324,
#  0.6489423127394888,
#  0.6606477350270327,
#  0.6707259461445594,
#  0.689570101307018,
#  0.706892026665267,
#  0.7294105296309905,
#  0.752926355571886,
#  0.7770195790247231,
#  0.7989606844785051]

# %%
sns.lineplot(x=range(1,15), y = teste, label = 'teste')
sns.lineplot(x=range(1,15), y = treino, label = 'treino')

# %%
pd.get_dummies(dados_combinados['tratamento'])
# Out:
#        com_controle  com_droga
# 0                 0          1
# 1                 0          1
# 2                 0          1
# 3                 0          1
# 4                 0          1
# ...             ...        ...
# 23809             0          1
# 23810             0          1
# 23811             1          0
# 23812             0          1
# 23813             0          1
#
# [23814 rows x 2 columns]

# %%
pd.get_dummies(dados_combinados, columns=['tratamento', 'dose', 'tempo'])
# Out:
#                  id   composto     g_0  ...  tempo_24  tempo_48  tempo_72
# 0      id_000644bb2  b68db1d53  1.0620  ...         1         0         0
# 1      id_000779bfc  df89a8e5a  0.0743  ...         0         0         1
# 2      id_000a6266a  18bb41b2c  0.6280  ...         0         1         0
# 3      id_0015fd391  8c7f86626 -0.5138  ...         0         1         0
# 4      id_001626bd3  7cbed3131 -0.3254  ...         0         0         1
# ...             ...        ...     ...  ...       ...       ...       ...
# 23809  id_fffb1ceed  df1d0a5a1  0.1394  ...         1         0         0
# 23810  id_fffb70c0c  ecf3b6b74 -1.3260  ...         1         0         0
# 23811  id_fffc1c3f4  cacb2b860  0.3942  ...         0         1         0
# 23812  id_fffcb9e7c  8b87a7a83  0.6660  ...         1         0         0
# 23813  id_ffffdd77b  972f41291 -0.8598  ...         0         0         1
#
# [23814 rows x 883 columns]

# %%
dados_combinados.drop(['id', 'n_moa', 'ativo_moa', 'composto'], axis=1)
# Out:
#          tratamento  tempo dose     g_0  ...    c_96    c_97    c_98    c_99
# 0         com_droga     24   D1  1.0620  ... -0.3981  0.2139  0.3801  0.4176
# 1         com_droga     72   D1  0.0743  ...  0.1522  0.1241  0.6077  0.7371
# 2         com_droga     48   D1  0.6280  ... -0.6417 -0.2187 -1.4080  0.6931
# 3         com_droga     48   D1 -0.5138  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4         com_droga     72   D2 -0.3254  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...    ...  ...     ...  ...     ...     ...     ...     ...
# 23809     com_droga     24   D2  0.1394  ...  0.0631  0.9171  0.5258  0.4680
# 23810     com_droga     24   D2 -1.3260  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  com_controle     48   D2  0.3942  ...  0.2256  0.7592  0.6656  0.3808
# 23812     com_droga     24   D1  0.6660  ...  0.1732  0.7015 -0.6290  0.0740
# 23813     com_droga     72   D1 -0.8598  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [23814 rows x 875 columns]

# %%
from sklearn.ensemble import RandomForestClassifier


x = dados_combinados.drop(['id', 'n_moa', 'ativo_moa', 'composto'], axis=1)
x = pd.get_dummies(x, columns=['tratamento', 'dose', 'tempo'])
y = dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x,y, test_size = 0.2, stratify=y, random_state = 376)

modelo_randomforest = RandomForestClassifier()
modelo_randomforest.fit(x_treino, y_treino)
modelo_randomforest.score(x_teste, y_teste)
# Out:
# 0.6829729162292673

# %% [markdown]
# ##Desafios

# %% [markdown]
# ###Desafio 01: Tente outros modelos ou mude os parâmetros dos modelos que testamos em aula.
#
# ###Desafio 02: Estude a documentação do Sklearn
#
# ###Desafio 03: Pesquisar o fluxograma "Escolhendo o melhor modelo"
#
# ###Desafio 04: Teste outros problemas (perguntas). 0,1 ou +.
#
# ###Desafio 05: Escolha a droga mais utilizada e tente criar um modelo para prever está label.
#
# ###Desafio 06: Resumo do que você aprendeu com os dados

# %% [markdown]
# ###Desafio 01: Tente outros modelos ou mude os parâmetros dos modelos que testamos em aula.

# %% [markdown]
# ####Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

x = dados_combinados.drop(['id', 'n_moa', 'ativo_moa', 'composto'], axis=1)
x = pd.get_dummies(x, columns=['tratamento', 'dose', 'tempo'])
y = dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x,y, test_size = 0.2, stratify=y, random_state = 376)

modelo_rlogistica = LogisticRegression(max_iter=1000)
modelo_rlogistica.fit(x_treino, y_treino)
modelo_rlogistica.score(x_teste, y_teste)
# Out:
# 0.6640772622296872

# %% [markdown]
# ####GridSearchCv

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier

# %%
EsPara = {
    'max_depth': [3,5],
    'min_samples_split': [32,64,128],
    'min_samples_leaf' : [32, 64, 128],
    'criterion' : ['gini', 'entropy']
}

# %%
x = dados_combinados.drop(['id', 'n_moa', 'ativo_moa', 'composto'], axis=1)
x = pd.get_dummies(x, columns=['tratamento', 'dose', 'tempo'])
y = dados_combinados['ativo_moa']

# %%
ModTree = DecisionTreeClassifier()

clf = GridSearchCV(ModTree, EsPara, cv = 5, return_train_score = True, scoring='accuracy')
search = clf.fit(x,y)
results_GridSearchCV = search.cv_results_
In_Best_Para = search.best_index_
#33m54s de execução, cuidado

# %%
print(f"mean_train_score {results_GridSearchCV['mean_train_score'][In_Best_Para]:.2f}")
print(f"mean_test_score {results_GridSearchCV['mean_test_score'][In_Best_Para]:.2f}")
# Out:
# mean_train_score 0.63
# mean_test_score 0.62

# %%
results_GridSearchCV['params'][In_Best_Para]
# Out:
# {'criterion': 'gini',
#  'max_depth': 5,
#  'min_samples_leaf': 32,
#  'min_samples_split': 32}

# %% [markdown]
# ###Desafio 02: Estude a documentação do Sklearn

# %% [markdown]
# https://scikit-learn.org/stable/index.html

# %% [markdown]
# ###Desafio 03: Pesquisar o fluxograma "Escolhendo o melhor modelo"

# %% [markdown]
# https://scikit-learn.org/stable/tutorial/machine_learning_map/index.html

# %% [markdown]
# ###Desafio 04: Teste outros problemas (perguntas). 0,1 ou +.

# %%
dados_combinados_2 = dados_combinados
dados_combinados_2['2+'] = (dados_combinados_2['n_moa'] >= 2)

# %%
dados_combinados_2
# Out:
#                  id    tratamento  tempo dose  ...    c_99  n_moa  ativo_moa     2+
# 0      id_000644bb2     com_droga     24   D1  ...  0.4176      1       True  False
# 1      id_000779bfc     com_droga     72   D1  ...  0.7371      0      False  False
# 2      id_000a6266a     com_droga     48   D1  ...  0.6931      3       True   True
# 3      id_0015fd391     com_droga     48   D1  ... -0.8154      0      False  False
# 4      id_001626bd3     com_droga     72   D2  ...  0.7125      1       True  False
# ...             ...           ...    ...  ...  ...     ...    ...        ...    ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.4680      1       True  False
# 23810  id_fffb70c0c     com_droga     24   D2  ...  0.3689      1       True  False
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.3808      0      False  False
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.0740      1       True  False
# ...

# %%
dados_combinados_2.query('n_moa >= 2')
# Out:
#                  id tratamento  tempo dose  ...    c_99  n_moa  ativo_moa    2+
# 2      id_000a6266a  com_droga     48   D1  ...  0.6931      3       True  True
# 11     id_0024bcd70  com_droga     48   D2  ...  0.3605      2       True  True
# 16     id_002fb9c19  com_droga     48   D1  ... -6.7840      2       True  True
# 18     id_003603254  com_droga     72   D2  ...  0.9765      4       True  True
# 21     id_003b43239  com_droga     48   D1  ... -0.5888      2       True  True
# ...             ...        ...    ...  ...  ...     ...    ...        ...   ...
# 23727  id_ff1d43f96  com_droga     24   D2  ... -3.2710      2       True  True
# 23732  id_ff24fc052  com_droga     72   D2  ... -0.0713      2       True  True
# 23776  id_ff9d0a022  com_droga     24   D2  ... -3.5610      2       True  True
# 23791  id_ffd1fd119  com_droga     72   D2  ... -4.6050      2       True  True
# 23802  id_fff3976bd  com_droga     24   D1  ... -3.7000      2       True  True
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier


x = dados_combinados_2.drop(['id', 'n_moa', 'ativo_moa', 'composto', '2+'], axis=1)
x = pd.get_dummies(x, columns=['tratamento', 'dose', 'tempo'])
y = dados_combinados_2['2+']
x_treino, x_teste, y_treino, y_teste = train_test_split(x,y, test_size = 0.2, stratify=y, random_state = 376)

modelo_randomforest = RandomForestClassifier()
modelo_randomforest.fit(x_treino, y_treino)
modelo_randomforest.score(x_teste, y_teste)
# Out:
# 0.9515011547344111

# %% [markdown]
# ###Desafio 05: Escolha a droga mais utilizada e tente criar um modelo para prever está label.

# %%
#Com a coluna 'composto'

from sklearn.ensemble import RandomForestClassifier


x = dados_combinados.drop(['id', 'n_moa', 'ativo_moa','tratamento'], axis=1)
x = pd.get_dummies(x, columns=['composto', 'dose', 'tempo'])
y = dados_combinados['tratamento']
x_treino, x_teste, y_treino, y_teste = train_test_split(x,y, test_size = 0.2, stratify=y, random_state = 376)

modelo_randomforest = RandomForestClassifier()
modelo_randomforest.fit(x_treino, y_treino)
modelo_randomforest.score(x_teste, y_teste)
# Out:
# 0.9424732311568339

# %%
#Sem a coluna 'composto'

from sklearn.ensemble import RandomForestClassifier


x = dados_combinados.drop(['id', 'n_moa', 'ativo_moa','tratamento','composto'], axis=1)
x = pd.get_dummies(x, columns=['dose', 'tempo'])
y = dados_combinados['tratamento']
x_treino, x_teste, y_treino, y_teste = train_test_split(x,y, test_size = 0.2, stratify=y, random_state = 376)

modelo_randomforest = RandomForestClassifier()
modelo_randomforest.fit(x_treino, y_treino)
modelo_randomforest.score(x_teste, y_teste)
# Out:
# 0.9296661767793407

# %% [markdown]
# ###Desafio 06: Resumo do que você aprendeu com os dados

# %% [markdown]
# Sobre a tabela em si não da para se aprender muito com as atividades de hoje. Porém, com os códigos, da para se aprender que a tecnica regression é um pouco menos efetiva que a Random Tree(para esse caso em especifico). Além de que, ao se exagerar no numero de "camadas" do metodo Tree normal, um overfit acontece em detrimento do quanto a maquina pratica com os dados de treino, se vendo uma piora alta na parte de resultados. Além, é claro, de que uma pesquisa feita a partir de um conjunto de dados menor é mais efetivo que um conjunto de dados maior, embora ainda não seja perfeita (o que não é um problema especificamente dependendo da questão, afinal, como pontuou a estrutora vanessa na aula, a ciencia não busca a perfeição, mas a melhora a cada dia).
